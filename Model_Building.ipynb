# %%
import Preprocessing_Function

# %% [markdown]
# #### Hey guys, I created this notebook so that you can jump right into the model building.
#
# ### Please note that our 4 categories are : style, occasion, category, and fit
#
# These 2 functions should take about 5~7 minutes to run.
# - ***'data'*** dataframe includes all the data for both labelled and unlabelled products. <br>
# - ***'data_label'*** dataframe only includes the products that are labelled already.
#
#
# You should should ***'data_label'*** to train and test the data. <br>
# If you have any question, look at the ***Data_Preprocessing*** notebook for details or just ask me!

# %%
data = Preprocessing_Function.import_data()
data
# Out:
#                        product_id                      brand           mpn  \
# 0      01dsrpsztdw2pgk1ywyxjgkzz0                       fila  400010319073
# 1      01dsqxjbx0r7dcw7ktac1sw547                     chanel  400011497371
# 2      01dpgv8tgrab993pf7z3ywg2vr                      frame      lwbt0099
# 3      01dsr8g3f7dbrtmp8thf97xsq2           lilli pulitz kid  400011844797
# 4      01dsr8g5gp519dedcskbmwqvk5                kissi kissi  400094474585
# ...                           ...                        ...           ...
# 48989  01e2kz045bct1q2z2pbc0cwrgh  atm anthoni thoma melillo       5441202
# 48990  01e2kxz0wnq96s64tdze3wb7cx  atm anthoni thoma melillo       5504588
# 48991  01e2kxwwy6jagened7p62090np  atm anthoni thoma melillo       4496777
# 48992  01e2kztepe7qk1v8thasf7hwnr  atm anthoni thoma melillo       5289605
# 48993  01e2ky2t6yv7r4vxt4bvv4twt5  atm anthoni thoma melillo       4788992
#
#                                                   name  \
# ...

# %%
data_label = Preprocessing_Function.labelled_data(data)
data_label
# Out:
#       index                  product_id                      brand      mpn  \
# 0         6  01dtjcerf6f4nrz2wsjffa1eys                     theori  1197027
# 1         8  01dvpbj6464ykygvae0a1hmkgn               alexand wang  1202011
# 2        10  01dpetns8db4mar29er6esa7xa                     j crew    b5275
# 3        11  01dt50zst2px9c1kkza4p73q5q               alexand wang  1154478
# 4        17  01dvcqrrx4qyjv20667zk52s82                     theori  1205277
# ...     ...                         ...                        ...      ...
# 3965  48989  01e2kz045bct1q2z2pbc0cwrgh  atm anthoni thoma melillo  5441202
# 3966  48990  01e2kxz0wnq96s64tdze3wb7cx  atm anthoni thoma melillo  5504588
# 3967  48991  01e2kxwwy6jagened7p62090np  atm anthoni thoma melillo  4496777
# 3968  48992  01e2kztepe7qk1v8thasf7hwnr  atm anthoni thoma melillo  5289605
# 3969  48993  01e2ky2t6yv7r4vxt4bvv4twt5  atm anthoni thoma melillo  4788992
#
# ...
