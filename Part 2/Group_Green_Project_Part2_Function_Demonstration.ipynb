# %%
import Group_Green_Project_Part2_Function

# %%
Group_Green_Project_Part2_Function.outfit_recommendation('01DMBRYVA2ZFDYRYY5TRQZJTBD')
# Out:
#                    product_id outfit_item_type          brand  \
# 0  01DMBRYVA2ZFDYRYY5TRQZJTBD             shoe     Tory Burch
# 1  01DMBRYVA2PEPWFTT7RMP5AA1T              top  Eileen Fisher
# 2  01DMBRYVA2P5H24WK0HTK4R0A1           bottom  Eileen Fisher
# 3  01DMBRYVA2Q2ST7MNYR6EEY4TK         onepiece      Equipment
#
#            product_full_name   description
# 0  Penelope Mid Cap Toe Pump   A nice shoe
# 1         Rib Mock Neck Tank   A nice tank
# 2            Slim Knit Skirt  A nice skirt
# 3        Chemelle Midi Dress  A nice dress

# %%
Group_Green_Project_Part2_Function.outfit_recommendation('Sexy silky, a-line mini skirt zipper Benson skirt')
# Out:
#                    product_id outfit_item_type        brand  \
# 0  01DPKMGJ33SDFXM7XHGPQJWQ12           bottom  Reformation
# 1  01DPGV74AR5GXBVYEZB86TS9PE             shoe        Frame
# 2  01DTATH8MJJNXGJYK2AF01E1W9         onepiece   Pippa Holt
#
#                         product_full_name  \
# 0                            Benson Skirt
# 1  FRAME x Tamara Mellon Slouch Knee Boot
# 2           Embroidered Cotton Mini Dress
#
#                                          description
# 0  Sexy silky. This is an a-line mini skirt with ...
# 1  This chic and minimal slouchy boot is a combin...
# 2  An abbreviated version of the caftans the labe...

# %%
Group_Green_Project_Part2_Function.outfit_recommendation('slim fitting, straight leg pant with a center back zipper and slightly cropped leg')
# Out:
#                    product_id outfit_item_type             brand  \
# 0  01DPKMH0D252JKMAA27MFCT5GM           bottom       Reformation
# 1  01DT2D3CE9PPPBBW8NYCZXMF6P       accessory1       Danse Lente
# 2  01DVA52ZCSNYK38PN2ZTM6E888              top  Carolina Herrera
#
#                              product_full_name  \
# 0                                  Marlon Pant
# 1  Phoebe Bis Two-Tone Croc-Effect Leather Bag
# 2          Collared Printed Cotton-Blend Shirt
#
#                                          description
# 0  Let your pants do the talking. This is a slim ...
# 1  Influenced by the bold shapes and colors of mo...
# 2  A hallmark of any Carolina Herrera show is the...
