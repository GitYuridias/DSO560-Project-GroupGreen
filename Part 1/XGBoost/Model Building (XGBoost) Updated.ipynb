# %% [markdown]
# # Packages and Data

# %%
import Preprocessing_Function
import pandas as pd
import numpy as np
import spacy
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.feature_extraction.text import TfidfVectorizer
import xgboost as xgb
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings("ignore")

# %%
## install if needed

#!python -m spacy download en_core_web_md

# %%
start = pd.datetime.now()

# %%
fulldata = Preprocessing_Function.import_data()
data_label = Preprocessing_Function.labelled_data(fulldata)

# %%
data = fulldata # full data
training = data_label # data with labels
data1 = data.copy() # copy
training1 = training.copy() # copy

# %%
nlp = spacy.load("en_core_web_md")

# %% [markdown]
# # Functions

# %%
# drop records with missing values for X-s and specified y
def getclean(df: pd.DataFrame(), y: str()):
    temp = df.copy()
    # drop redundant index columns
    temp.drop(['index'], axis = 1, inplace = True)
    # remove records with missing data for X-s and y (here - category)
    temp.dropna(subset=['brand','description','details',y], inplace = True)
    temp.reset_index(inplace = True)
    temp.drop('index', axis = 1, inplace = True)
    return temp

# %%
# vectorize descriptions in df using doc2vecs trained on fulL_data descriptions
def doc2vecdesc(df: pd.DataFrame()):
    temp = data1.copy()
    temp.dropna(subset = ['description'], inplace = True)
    temp.reset_index(inplace = True)
    temp.drop(['index'], axis = 1, inplace = True)
    # retrieve description documents
    documents = [TaggedDocument(str(temp.loc[i,'description']), [i]) for i in temp.index]
    # train doc2vec on full data descriptions and vectorize training documents
    model = Doc2Vec(documents, vector_size=300, window=3, workers=4)
    df['VectorizedDesc'] = df.description.apply(lambda x: model.infer_vector([x]))
    description_vectors = list(df.VectorizedDesc.values)
    return description_vectors

# %%
# tf-idf doc vectorization for names and details
def tfidfvectorize(x: list()):
    # tf-idf vectorize on all unique tokens in list 'x' and sum the scores for each doc
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(x)
    tf_idf_lookup_table = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())
    DOCUMENT_SUM_COLUMN = "DOCUMENT_TF_IDF_SUM"
    tf_idf_lookup_table[DOCUMENT_SUM_COLUMN] = tf_idf_lookup_table.sum(axis=1)
    # create a list of all tokens extracted by tf-idf
    available_tf_idf_scores = tf_idf_lookup_table.columns
    available_tf_idf_scores = list(map(lambda x: x, available_tf_idf_scores))
    # define an empty list
    docvectors = []
    # obtain tf-idf doc embeddings for every element in 'x'
    for idx, x in enumerate(x): 
        tokens = nlp(x)
        total_tf_idf_score_per_document = 0
        running_total_word_embedding = np.zeros(300) 
        for token in tokens:
            if token.has_vector and token.text in available_tf_idf_scores:
                tf_idf_score = tf_idf_lookup_table.loc[idx, token.text]
                running_total_word_embedding += tf_idf_score * token.vector
                total_tf_idf_score_per_document += tf_idf_score
        document_embedding = running_total_word_embedding / total_tf_idf_score_per_document
        docvectors.append(document_embedding)
    # return the embeddings
    return docvectors

# %%
## function to perform classification for single-label targets (using softmax as our 'activation')
# preparing the data for xgboost, which is then run in this function 
# takes about 5-7 minutes to run with 100 trees and 5 folds
def softmax(df: pd.DataFrame(), description_vectors: list(), names_vectors: list(), details_vectors: list(),\
            attribute: str(), fold: int(), seed: int()):
    brandsdf = pd.get_dummies(df.brand)
    namesdf = pd.DataFrame(np.array(names_vectors))
    detailsdf = pd.DataFrame(np.array(details_vectors))
    descriptiondf = pd.DataFrame(np.array(description_vectors))
    X = pd.concat([brandsdf,namesdf,detailsdf,descriptiondf], axis = 1) # combine embeddings into a data frame
    X.columns = [f'col{i}' for i in range(X.shape[1])]
    d = {}
    for i in range(len(df[attribute].unique())):
        d.update({df[attribute].unique()[i]: i}) # create a dicionary where a unique attribute from class is stored as key 
                                                 # and is assigned a unique index as value
    y = df[attribute].map(d) # map keys to values
    kf = KFold(n_splits = fold, random_state = seed, shuffle = True) # define the k-fold constructor
    temp = []
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        # define the constructor, where hyperparameters were tuned using GridSearchCV on 1350 different combinations of 
        # parameters ['max_depth','n_estimators','reg_lambda','learning_rate','colsample_bytree']
        clf = xgb.XGBClassifier(max_depth=8, objective='multi:softprob', n_estimators=100, reg_lambda=0.25,\
                         learning_rate=0.1,colsample_bytree=0.25,num_classes=len(y.unique()))
        clf.fit(X_train, y_train)  
        pred = clf.predict(X_test)
        temp.append(np.mean(pred != y_test)) # misclassification rate 
    accuracy = f'{attribute} accuracy: {(1-np.mean(temp))*100}'
    d = {j:i for i,j in d.items()}
    y_test = y_test.reset_index()
    y_test = pd.Series(y_test[attribute])
    y_test = y_test.map(d) # map back the actual labels
    pred = pd.Series(pred)
    pred = pred.map(d) # map back the actual labels
    temp = pd.DataFrame({f'{attribute}_actual': y_test, f'{attribute}_predicted': pred}) # combine into a df
    results = [accuracy, temp]    # accuracy over all folds, sample (by default last iteration of Kfold) actual labels,
                                  # and sample predicted labels
    return results

# %%
## function to perform classification for multi-label targets (using sigmoid as our 'activation')
# preparing the data for xgboost, which is then run in this function
# takes about 5-7 minutes to run with 100 trees and 5 folds
def sigmoid(df: pd.DataFrame(), description_vectors: list(), names_vectors: list(), details_vectors: list(),\
            attribute: str(), fold: int(), seed: int()):
    brandsdf = pd.get_dummies(df.brand)
    namesdf = pd.DataFrame(np.array(names_vectors))
    detailsdf = pd.DataFrame(np.array(details_vectors))
    descriptiondf = pd.DataFrame(np.array(description_vectors))
    X = pd.concat([brandsdf,namesdf,detailsdf,descriptiondf], axis = 1) # combine embeddings into a data frame
    X.columns = [f'col{i}' for i in range(X.shape[1])]
    l = []
    for i in range(X.shape[0]):
        for j in df.loc[i,attribute].split(' '):
            if j not in l:
                l.append(j) # retrieve all unique attributes from class and store them in a list
    results = []
    for subattr in l: # iterate xgboost over each unique attribute - resulting in a separate model for every attribute
        y = df[attribute].apply(lambda x: 1 if subattr in x.split(' ') else 0)
        kf = KFold(n_splits = fold, random_state = seed, shuffle = True)
        temp = []
        for train_index, test_index in kf.split(X):
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]
            # define the constructor, where hyperparameters were tuned using GridSearchCV on 1350 different combinations of 
            # parameters ['max_depth','n_estimators','reg_lambda','learning_rate','colsample_bytree']
            clf = xgb.XGBClassifier(max_depth=8, objective='binary:logistic', n_estimators=100, reg_lambda=0.25,\
                             learning_rate=0.1,colsample_bytree=0.25,num_classes=len(y.unique()))
            clf.fit(X_train, y_train)  
            pred = clf.predict(X_test)
            temp.append(np.mean(pred != y_test)) # misclassification rate
        accuracy = f'{attribute} accuracy: {(1-np.mean(temp))*100}'
        y_test = y_test.reset_index()
        y_test = pd.Series(y_test[attribute])
        y_test = y_test.apply(lambda x: f'{subattr}' if x else f'not {subattr}') # 0 (not a match) is translated 
                                                                                 # into 'not subattribute'
        pred = pd.Series(pred)
        pred = pred.apply(lambda x: f'{subattr}' if x else f'not {subattr}')     # 0 (not a match) is translated 
                                                                                 # into 'not subattribute'
        temp = pd.DataFrame({f'{attribute}_{subattr}_actual': y_test, f'{attribute}_{subattr}_predicted': pred})
        results.append([accuracy, temp])  # accuracy over all folds, sample (by default last iteration of Kfold) actual labels,
                                          # and sample predicted labels for the selected subattribute in an attribute
    return results

# %% [markdown]
# # Example for 'Category'

# %%
training = getclean(training1, 'category')
training.shape[0] # 3321 records where X-s and y (category) are not NaN
# Out:
# 3321

# %%
description_vectors = doc2vecdesc(training)

# %%
brand_vectors = list(pd.get_dummies(training.brand).values)

# %%
names = list(training.name.values)
details = list(training.details.values)

# %%
names_vectors = tfidfvectorize(names)
details_vectors = tfidfvectorize(details)

# %%
check = [len(description_vectors)-training.shape[0],len(brand_vectors)-training.shape[0],\
         len(names_vectors)-training.shape[0], len(details_vectors)-training.shape[0]]
not any(check) # 'True' here indicates that all embedded objects have the same number of documents as does the 'training' df
# Out:
# True

# %%
catlist = softmax(training,description_vectors,names_vectors,details_vectors,'category',2,2) 
# using 2 folds and random.seed = 2

# %%
catlist
# Out:
# ['category accuracy: 81.8126690990331',
#         category_actual category_predicted
#  0                  top                top
#  1             onepiece           onepiece
#  2               bottom             bottom
#  3             onepiece           onepiece
#  4             onepiece             bottom
#  ...                ...                ...
#  1655               top                top
#  1656               top                top
#  1657  sweatshirthoodie                top
#  1658            bottom             bottom
#  1659            bottom             bottom
#
#  [1660 rows x 2 columns]]

# %% [markdown]
# # General form

# %%
def combine(df: pd.DataFrame(), fold: int(), seed: int()):
    results = []
    for i in ['category','embellishment','style','occasion']: # iterate through each selected class to predict
        training = getclean(df, i) # cleaned data (accounting for NA-s) according to the selected class
        description_vectors = doc2vecdesc(training) # description embeddings
        brand_vectors = list(pd.get_dummies(training.brand).values) # one-hot encoded brands
        names = list(training.name.values) # product names
        details = list(training.details.values) # product details
        names_vectors = tfidfvectorize(names) # product name embeddings
        details_vectors = tfidfvectorize(details) # product details embeddings
        check = [len(description_vectors)-training.shape[0],len(brand_vectors)-training.shape[0],\
                 len(names_vectors)-training.shape[0], len(details_vectors)-training.shape[0]] 
        # any(check) == 'False' here indicates that all embedded objects have the same number of documents 
        # as does the 'training' df
        if any(check):
            return f'Error: Number of embedded rows does not match the number of labeled records for class {i}'
        if i == 'category':
            results.append(softmax(training,description_vectors,names_vectors,details_vectors,i,fold,seed)) # single-label
        else:
            results.append(sigmoid(training,description_vectors,names_vectors,details_vectors,i,fold,seed)) # multi-label
    return results

# %%
classlist = combine(training1,5,0) # 5+ fold CV-s are encouraged, but take significantly more time to output

# %%
classlist
# Out:
# [['category accuracy: 83.1069843282906',
#         category_actual category_predicted
#   0                 top                top
#   1            onepiece           onepiece
#   2            onepiece           onepiece
#   3                shoe               shoe
#   4                shoe               shoe
#   ..                ...                ...
#   659               top                top
#   660               top                top
#   661  sweatshirthoodie                top
#   662               top                top
#   663               top                top
#
#   [664 rows x 2 columns]],
#  [['embellishment accuracy: 96.20689655172414',
#       embellishment_sequins_actual embellishment_sequins_predicted
#    0                   not sequins                     not sequins
#    1                   not sequins                     not sequins
#    2                   not sequins                     not sequins
#    3                   not sequins                     not sequins
#    4                   not sequins                     not sequins
#    5                   not sequins                     not sequins
#    6                   not sequins                     not sequins
#    7                   not sequins                     not sequins
#    8                   not sequins                     not sequins
#    9                   not sequins                     not sequins
#    10                  not sequins                     not sequins
#    11                  not sequins                     not sequins
#    12                  not sequins                     not sequins
#    13                  not sequins                     not sequins
#    14                  not sequins                     not sequins
#    15                  not sequins                     not sequins
#    16                  not sequins                     not sequins
#    17                  not sequins                     not sequins
#    18                  not sequins                     not sequins
#    19                  not sequins                     not sequins
#    20                  not sequins                     not sequins
#    21                  not sequins                     not sequins
#    22                  not sequins                     not sequins
#    23                  not sequins                     not sequins
#    24                  not sequins                     not sequins
#    25                  not sequins                     not sequins
#    26                  not sequins                     not sequins
#    27                  not sequins                     not sequins
#    28                  not sequins                     not sequins
#    29                  not sequins                     not sequins
#    30                  not sequins                     not sequins
#    31                  not sequins                     not sequins
#    32                  not sequins                     not sequins
#    33                  not sequins                     not sequins
#    34                  not sequins                     not sequins
#    35                  not sequins                     not sequins
#    36                  not sequins                     not sequins
#    37                  not sequins                     not sequins
#    38                  not sequins                     not sequins
#    39                  not sequins                     not sequins
#    40                  not sequins                     not sequins
#    41                  not sequins                     not sequins
#    42                  not sequins                     not sequins
#    43                  not sequins                     not sequins
#    44                  not sequins                     not sequins
#    45                  not sequins                     not sequins
#    46                  not sequins                     not sequins
#    47                  not sequins                     not sequins
#    48                  not sequins                     not sequins
#    49                  not sequins                     not sequins
#    50                  not sequins                     not sequins
#    51                  not sequins                     not sequins
#    52                  not sequins                     not sequins
#    53                  not sequins                     not sequins
#    54                  not sequins                     not sequins
#    55                  not sequins                     not sequins
#    56                  not sequins                     not sequins
#    57                  not sequins                     not sequins],
#   ['embellishment accuracy: 88.96551724137932',
#       embellishment_trim_actual embellishment_trim_predicted
#    0                   not trim                     not trim
#    1                   not trim                     not trim
#    2                       trim                     not trim
#    3                   not trim                     not trim
#    4                   not trim                     not trim
#    5                   not trim                     not trim
#    6                   not trim                     not trim
#    7                   not trim                     not trim
#    8                   not trim                     not trim
#    9                   not trim                     not trim
#    10                  not trim                     not trim
#    11                  not trim                     not trim
#    12                  not trim                     not trim
#    13                  not trim                     not trim
#    14                  not trim                     not trim
#    15                  not trim                     not trim
#    16                  not trim                     not trim
#    17                  not trim                     not trim
#    18                  not trim                     not trim
#    19                  not trim                     not trim
#    20                      trim                     not trim
#    21                  not trim                     not trim
#    22                  not trim                     not trim
#    23                      trim                     not trim
#    24                  not trim                     not trim
#    25                  not trim                     not trim
#    26                  not trim                     not trim
#    27                  not trim                     not trim
#    28                  not trim                     not trim
#    29                      trim                     not trim
#    30                  not trim                     not trim
#    31                  not trim                     not trim
#    32                  not trim                     not trim
#    33                  not trim                     not trim
#    34                  not trim                     not trim
#    35                  not trim                     not trim
#    36                  not trim                     not trim
#    37                  not trim                     not trim
#    38                  not trim                     not trim
#    39                  not trim                     not trim
#    40                  not trim                     not trim
#    41                  not trim                     not trim
#    42                  not trim                     not trim
#    43                  not trim                     not trim
#    44                      trim                     not trim
#    45                  not trim                     not trim
#    46                      trim                     not trim
#    47                      trim                     not trim
#    48                  not trim                     not trim
#    49                  not trim                     not trim
#    50                  not trim                     not trim
#    51                  not trim                     not trim
#    52                  not trim                     not trim
#    53                  not trim                     not trim
#    54                  not trim                     not trim
#    55                  not trim                     not trim
#    56                  not trim                     not trim
#    57                  not trim                     not trim],
#   ['embellishment accuracy: 78.62068965517241',
#       embellishment_ruffles_actual embellishment_ruffles_predicted
#    0                   not ruffles                     not ruffles
#    1                   not ruffles                     not ruffles
#    2                   not ruffles                         ruffles
#    3                       ruffles                     not ruffles
#    4                   not ruffles                     not ruffles
#    5                   not ruffles                     not ruffles
#    6                       ruffles                     not ruffles
#    7                   not ruffles                     not ruffles
#    8                   not ruffles                     not ruffles
#    9                   not ruffles                     not ruffles
#    10                  not ruffles                     not ruffles
#    11                      ruffles                     not ruffles
#    12                      ruffles                     not ruffles
#    13                      ruffles                     not ruffles
#    14                  not ruffles                     not ruffles
#    15                  not ruffles                     not ruffles
#    16                      ruffles                     not ruffles
#    17                  not ruffles                     not ruffles
#    18                  not ruffles                     not ruffles
#    19                      ruffles                     not ruffles
#    20                  not ruffles                     not ruffles
#    21                  not ruffles                     not ruffles
#    22                      ruffles                     not ruffles
#    23                  not ruffles                     not ruffles
#    24                      ruffles                     not ruffles
#    25                  not ruffles                     not ruffles
#    26                  not ruffles                     not ruffles
#    27                  not ruffles                     not ruffles
#    28                  not ruffles                     not ruffles
#    29                  not ruffles                     not ruffles
#    30                  not ruffles                         ruffles
#    31                  not ruffles                     not ruffles
#    32                  not ruffles                     not ruffles
#    33                  not ruffles                     not ruffles
#    34                  not ruffles                     not ruffles
#    35                  not ruffles                     not ruffles
#    36                  not ruffles                     not ruffles
#    37                  not ruffles                     not ruffles
#    38                  not ruffles                     not ruffles
#    39                  not ruffles                     not ruffles
#    40                  not ruffles                     not ruffles
#    41                  not ruffles                     not ruffles
#    42                  not ruffles                     not ruffles
#    43                  not ruffles                     not ruffles
#    44                  not ruffles                     not ruffles
#    45                  not ruffles                     not ruffles
#    46                  not ruffles                     not ruffles
#    47                  not ruffles                     not ruffles
#    48                  not ruffles                     not ruffles
#    49                      ruffles                     not ruffles
#    50                  not ruffles                     not ruffles
#    51                  not ruffles                     not ruffles
#    52                      ruffles                     not ruffles
#    53                      ruffles                         ruffles
#    54                      ruffles                         ruffles
#    55                  not ruffles                     not ruffles
#    56                  not ruffles                     not ruffles
#    57                  not ruffles                     not ruffles],
#   ['embellishment accuracy: 89.3103448275862',
#       embellishment_studs_actual embellishment_studs_predicted
#    0                   not studs                     not studs
#    1                   not studs                     not studs
#    2                   not studs                     not studs
#    3                   not studs                     not studs
#    4                   not studs                     not studs
#    5                   not studs                     not studs
#    6                   not studs                     not studs
#    7                   not studs                     not studs
#    8                   not studs                     not studs
#    9                   not studs                     not studs
#    10                  not studs                     not studs
#    11                  not studs                     not studs
#    12                  not studs                     not studs
#    13                  not studs                     not studs
#    14                  not studs                     not studs
#    15                  not studs                     not studs
#    16                  not studs                     not studs
#    17                  not studs                     not studs
#    18                  not studs                     not studs
#    19                  not studs                     not studs
#    20                  not studs                     not studs
#    21                  not studs                     not studs
#    22                  not studs                     not studs
#    23                  not studs                     not studs
#    24                  not studs                     not studs
#    25                  not studs                     not studs
#    26                  not studs                     not studs
#    27                  not studs                     not studs
#    28                  not studs                     not studs
#    29                  not studs                     not studs
#    30                  not studs                     not studs
#    31                  not studs                     not studs
#    32                  not studs                     not studs
#    33                      studs                         studs
#    34                      studs                         studs
#    35                  not studs                     not studs
#    36                      studs                         studs
#    37                      studs                         studs
#    38                  not studs                     not studs
#    39                      studs                     not studs
#    40                      studs                         studs
#    41                  not studs                     not studs
#    42                  not studs                     not studs
#    43                  not studs                     not studs
#    44                  not studs                     not studs
#    45                  not studs                     not studs
#    46                  not studs                     not studs
#    47                  not studs                     not studs
#    48                  not studs                     not studs
#    49                  not studs                     not studs
#    50                  not studs                     not studs
#    51                      studs                     not studs
#    52                  not studs                     not studs
#    53                  not studs                     not studs
#    54                  not studs                     not studs
#    55                  not studs                         studs
#    56                      studs                     not studs
#    57                  not studs                         studs],
#   ['embellishment accuracy: 93.44827586206897',
#       embellishment_mesh_actual embellishment_mesh_predicted
#    0                   not mesh                     not mesh
#    1                   not mesh                     not mesh
#    2                   not mesh                     not mesh
#    3                   not mesh                     not mesh
#    4                   not mesh                     not mesh
#    5                   not mesh                     not mesh
#    6                   not mesh                     not mesh
#    7                   not mesh                     not mesh
#    8                   not mesh                     not mesh
#    9                       mesh                     not mesh
#    10                      mesh                     not mesh
#    11                  not mesh                     not mesh
#    12                  not mesh                     not mesh
#    13                  not mesh                     not mesh
#    14                      mesh                     not mesh
#    15                  not mesh                     not mesh
#    16                  not mesh                     not mesh
#    17                  not mesh                     not mesh
#    18                  not mesh                     not mesh
#    19                  not mesh                     not mesh
#    20                  not mesh                     not mesh
#    21                  not mesh                     not mesh
#    22                  not mesh                     not mesh
#    23                  not mesh                     not mesh
#    24                  not mesh                     not mesh
#    25                  not mesh                     not mesh
#    26                  not mesh                     not mesh
#    27                  not mesh                     not mesh
#    28                  not mesh                     not mesh
#    29                  not mesh                     not mesh
#    30                  not mesh                     not mesh
#    31                  not mesh                     not mesh
#    32                  not mesh                     not mesh
#    33                  not mesh                     not mesh
#    34                  not mesh                     not mesh
#    35                  not mesh                     not mesh
#    36                  not mesh                     not mesh
#    37                  not mesh                     not mesh
#    38                  not mesh                     not mesh
#    39                  not mesh                     not mesh
#    40                  not mesh                     not mesh
#    41                  not mesh                     not mesh
#    42                  not mesh                     not mesh
#    43                  not mesh                     not mesh
#    44                  not mesh                     not mesh
#    45                  not mesh                     not mesh
#    46                  not mesh                     not mesh
#    47                  not mesh                     not mesh
#    48                  not mesh                     not mesh
#    49                  not mesh                     not mesh
#    50                  not mesh                     not mesh
#    51                  not mesh                     not mesh
#    52                  not mesh                     not mesh
#    53                  not mesh                     not mesh
#    54                  not mesh                     not mesh
#    55                  not mesh                     not mesh
#    56                  not mesh                     not mesh
#    57                  not mesh                     not mesh],
#   ['embellishment accuracy: 93.44827586206897',
#       embellishment_lace_actual embellishment_lace_predicted
#    0                   not lace                     not lace
#    1                   not lace                     not lace
#    2                   not lace                     not lace
#    3                   not lace                     not lace
#    4                   not lace                     not lace
#    5                   not lace                     not lace
#    6                   not lace                     not lace
#    7                   not lace                     not lace
#    8                   not lace                     not lace
#    9                   not lace                     not lace
#    10                      lace                     not lace
#    11                  not lace                     not lace
#    12                  not lace                     not lace
#    13                  not lace                     not lace
#    14                  not lace                     not lace
#    15                      lace                     not lace
#    16                  not lace                     not lace
#    17                  not lace                     not lace
#    18                  not lace                     not lace
#    19                  not lace                     not lace
#    20                  not lace                     not lace
#    21                  not lace                     not lace
#    22                  not lace                     not lace
#    23                  not lace                     not lace
#    24                  not lace                     not lace
#    25                  not lace                     not lace
#    26                  not lace                     not lace
#    27                  not lace                     not lace
#    28                  not lace                     not lace
#    29                  not lace                     not lace
#    30                  not lace                     not lace
#    31                  not lace                     not lace
#    32                  not lace                     not lace
#    33                  not lace                     not lace
#    34                  not lace                     not lace
#    35                  not lace                     not lace
#    36                  not lace                     not lace
#    37                  not lace                     not lace
#    38                  not lace                     not lace
#    39                  not lace                     not lace
#    40                  not lace                     not lace
#    41                  not lace                     not lace
#    42                      lace                     not lace
#    43                  not lace                     not lace
#    44                  not lace                     not lace
#    45                  not lace                     not lace
#    46                  not lace                     not lace
#    47                  not lace                     not lace
#    48                  not lace                     not lace
#    49                  not lace                     not lace
#    50                  not lace                     not lace
#    51                  not lace                     not lace
#    52                  not lace                     not lace
#    53                  not lace                     not lace
#    54                  not lace                     not lace
#    55                  not lace                     not lace
#    56                  not lace                     not lace
#    57                  not lace                     not lace],
#   ['embellishment accuracy: 94.82758620689656',
#       embellishment_fringe_actual embellishment_fringe_predicted
#    0                       fringe                     not fringe
#    1                   not fringe                     not fringe
#    2                   not fringe                     not fringe
#    3                   not fringe                     not fringe
#    4                   not fringe                     not fringe
#    5                       fringe                     not fringe
#    6                   not fringe                     not fringe
#    7                   not fringe                     not fringe
#    8                   not fringe                     not fringe
#    9                   not fringe                     not fringe
#    10                  not fringe                     not fringe
#    11                  not fringe                     not fringe
#    12                  not fringe                     not fringe
#    13                  not fringe                     not fringe
#    14                  not fringe                     not fringe
#    15                  not fringe                     not fringe
#    16                  not fringe                     not fringe
#    17                  not fringe                     not fringe
#    18                  not fringe                     not fringe
#    19                  not fringe                     not fringe
#    20                  not fringe                     not fringe
#    21                  not fringe                     not fringe
#    22                  not fringe                     not fringe
#    23                  not fringe                     not fringe
#    24                  not fringe                     not fringe
#    25                  not fringe                     not fringe
#    26                  not fringe                     not fringe
#    27                      fringe                     not fringe
#    28                  not fringe                     not fringe
#    29                  not fringe                     not fringe
#    30                  not fringe                     not fringe
#    31                  not fringe                     not fringe
#    32                  not fringe                     not fringe
#    33                  not fringe                     not fringe
#    34                  not fringe                     not fringe
#    35                      fringe                     not fringe
#    36                  not fringe                     not fringe
#    37                  not fringe                     not fringe
#    38                  not fringe                     not fringe
#    39                  not fringe                     not fringe
#    40                  not fringe                     not fringe
#    41                      fringe                     not fringe
#    42                  not fringe                     not fringe
#    43                      fringe                     not fringe
#    44                  not fringe                     not fringe
#    45                  not fringe                     not fringe
#    46                  not fringe                     not fringe
#    47                  not fringe                     not fringe
#    48                  not fringe                     not fringe
#    49                  not fringe                     not fringe
#    50                  not fringe                     not fringe
#    51                  not fringe                     not fringe
#    52                  not fringe                     not fringe
#    53                  not fringe                     not fringe
#    54                  not fringe                     not fringe
#    55                  not fringe                     not fringe
#    56                  not fringe                     not fringe
#    57                  not fringe                     not fringe],
#   ['embellishment accuracy: 89.3103448275862',
#       embellishment_embroidery_actual embellishment_embroidery_predicted
#    0                   not embroidery                     not embroidery
#    1                   not embroidery                     not embroidery
#    2                   not embroidery                     not embroidery
#    3                   not embroidery                     not embroidery
#    4                       embroidery                     not embroidery
#    5                   not embroidery                     not embroidery
#    6                   not embroidery                     not embroidery
#    7                   not embroidery                     not embroidery
#    8                   not embroidery                     not embroidery
#    9                   not embroidery                     not embroidery
#    10                  not embroidery                     not embroidery
#    11                  not embroidery                     not embroidery
#    12                  not embroidery                     not embroidery
#    13                  not embroidery                     not embroidery
#    14                  not embroidery                     not embroidery
#    15                  not embroidery                     not embroidery
#    16                  not embroidery                     not embroidery
#    17                  not embroidery                         embroidery
#    18                  not embroidery                     not embroidery
#    19                  not embroidery                     not embroidery
#    20                  not embroidery                     not embroidery
#    21                  not embroidery                     not embroidery
#    22                  not embroidery                     not embroidery
#    23                  not embroidery                     not embroidery
#    24                  not embroidery                     not embroidery
#    25                  not embroidery                     not embroidery
#    26                  not embroidery                     not embroidery
#    27                  not embroidery                     not embroidery
#    28                  not embroidery                     not embroidery
#    29                  not embroidery                     not embroidery
#    30                      embroidery                     not embroidery
#    31                  not embroidery                     not embroidery
#    32                      embroidery                     not embroidery
#    33                  not embroidery                     not embroidery
#    34                  not embroidery                     not embroidery
#    35                  not embroidery                     not embroidery
#    36                  not embroidery                     not embroidery
#    37                  not embroidery                     not embroidery
#    38                  not embroidery                     not embroidery
#    39                  not embroidery                     not embroidery
#    40                  not embroidery                     not embroidery
#    41                  not embroidery                     not embroidery
#    42                  not embroidery                     not embroidery
#    43                  not embroidery                     not embroidery
#    44                  not embroidery                     not embroidery
#    45                  not embroidery                     not embroidery
#    46                  not embroidery                     not embroidery
#    47                  not embroidery                     not embroidery
#    48                  not embroidery                     not embroidery
#    49                  not embroidery                     not embroidery
#    50                  not embroidery                     not embroidery
#    51                  not embroidery                     not embroidery
#    52                  not embroidery                     not embroidery
#    53                  not embroidery                     not embroidery
#    54                  not embroidery                     not embroidery
#    55                  not embroidery                     not embroidery
#    56                  not embroidery                     not embroidery
#    57                  not embroidery                     not embroidery],
#   ['embellishment accuracy: 91.72413793103449',
#       embellishment_buckles_actual embellishment_buckles_predicted
#    0                   not buckles                     not buckles
#    1                       buckles                     not buckles
#    2                   not buckles                     not buckles
#    3                   not buckles                     not buckles
#    4                   not buckles                     not buckles
#    5                   not buckles                     not buckles
#    6                   not buckles                     not buckles
#    7                       buckles                     not buckles
#    8                       buckles                     not buckles
#    9                   not buckles                     not buckles
#    10                  not buckles                     not buckles
#    11                  not buckles                     not buckles
#    12                  not buckles                     not buckles
#    13                  not buckles                     not buckles
#    14                  not buckles                     not buckles
#    15                  not buckles                     not buckles
#    16                  not buckles                     not buckles
#    17                  not buckles                     not buckles
#    18                  not buckles                     not buckles
#    19                  not buckles                     not buckles
#    20                  not buckles                     not buckles
#    21                  not buckles                     not buckles
#    22                  not buckles                     not buckles
#    23                  not buckles                     not buckles
#    24                  not buckles                     not buckles
#    25                  not buckles                     not buckles
#    26                  not buckles                     not buckles
#    27                  not buckles                     not buckles
#    28                  not buckles                     not buckles
#    29                  not buckles                     not buckles
#    30                  not buckles                     not buckles
#    31                  not buckles                     not buckles
#    32                  not buckles                     not buckles
#    33                  not buckles                     not buckles
#    34                  not buckles                     not buckles
#    35                  not buckles                     not buckles
#    36                  not buckles                     not buckles
#    37                  not buckles                     not buckles
#    38                      buckles                         buckles
#    39                  not buckles                     not buckles
#    40                  not buckles                     not buckles
#    41                  not buckles                     not buckles
#    42                  not buckles                     not buckles
#    43                  not buckles                         buckles
#    44                  not buckles                     not buckles
#    45                  not buckles                     not buckles
#    46                  not buckles                     not buckles
#    47                  not buckles                     not buckles
#    48                  not buckles                     not buckles
#    49                  not buckles                     not buckles
#    50                      buckles                     not buckles
#    51                  not buckles                     not buckles
#    52                  not buckles                     not buckles
#    53                  not buckles                     not buckles
#    54                  not buckles                     not buckles
#    55                  not buckles                     not buckles
#    56                  not buckles                     not buckles
#    57                  not buckles                     not buckles],
#   ['embellishment accuracy: 96.55172413793103',
#       embellishment_crystals_actual embellishment_crystals_predicted
#    0                   not crystals                     not crystals
#    1                   not crystals                     not crystals
#    2                   not crystals                     not crystals
#    3                   not crystals                     not crystals
#    4                   not crystals                     not crystals
#    5                   not crystals                     not crystals
#    6                   not crystals                     not crystals
#    7                   not crystals                     not crystals
#    8                   not crystals                     not crystals
#    9                   not crystals                     not crystals
#    10                  not crystals                     not crystals
#    11                  not crystals                     not crystals
#    12                  not crystals                     not crystals
#    13                  not crystals                     not crystals
#    14                  not crystals                     not crystals
#    15                  not crystals                     not crystals
#    16                  not crystals                     not crystals
#    17                  not crystals                     not crystals
#    18                  not crystals                     not crystals
#    19                  not crystals                     not crystals
#    20                  not crystals                     not crystals
#    21                      crystals                     not crystals
#    22                  not crystals                     not crystals
#    23                  not crystals                     not crystals
#    24                  not crystals                     not crystals
#    25                  not crystals                     not crystals
#    26                  not crystals                     not crystals
#    27                  not crystals                     not crystals
#    28                  not crystals                     not crystals
#    29                  not crystals                     not crystals
#    30                  not crystals                     not crystals
#    31                  not crystals                     not crystals
#    32                  not crystals                     not crystals
#    33                  not crystals                     not crystals
#    34                  not crystals                     not crystals
#    35                  not crystals                     not crystals
#    36                  not crystals                     not crystals
#    37                  not crystals                     not crystals
#    38                  not crystals                     not crystals
#    39                  not crystals                     not crystals
#    40                  not crystals                     not crystals
#    41                  not crystals                     not crystals
#    42                  not crystals                     not crystals
#    43                  not crystals                     not crystals
#    44                  not crystals                     not crystals
#    45                  not crystals                     not crystals
#    46                  not crystals                     not crystals
#    47                  not crystals                     not crystals
#    48                      crystals                     not crystals
#    49                  not crystals                     not crystals
#    50                  not crystals                     not crystals
#    51                  not crystals                     not crystals
#    52                  not crystals                     not crystals
#    53                  not crystals                     not crystals
#    54                  not crystals                     not crystals
#    55                  not crystals                     not crystals
#    56                  not crystals                     not crystals
#    57                  not crystals                     not crystals],
#   ['embellishment accuracy: 96.55172413793103',
#       embellishment_rhinestone_actual embellishment_rhinestone_predicted
#    0                   not rhinestone                     not rhinestone
#    1                   not rhinestone                     not rhinestone
#    2                   not rhinestone                     not rhinestone
#    3                   not rhinestone                     not rhinestone
#    4                   not rhinestone                     not rhinestone
#    5                   not rhinestone                     not rhinestone
#    6                   not rhinestone                     not rhinestone
#    7                   not rhinestone                     not rhinestone
#    8                   not rhinestone                     not rhinestone
#    9                   not rhinestone                     not rhinestone
#    10                  not rhinestone                     not rhinestone
#    11                  not rhinestone                     not rhinestone
#    12                  not rhinestone                     not rhinestone
#    13                  not rhinestone                     not rhinestone
#    14                  not rhinestone                     not rhinestone
#    15                  not rhinestone                     not rhinestone
#    16                  not rhinestone                     not rhinestone
#    17                  not rhinestone                     not rhinestone
#    18                  not rhinestone                     not rhinestone
#    19                  not rhinestone                     not rhinestone
#    20                  not rhinestone                     not rhinestone
#    21                  not rhinestone                     not rhinestone
#    22                  not rhinestone                     not rhinestone
#    23                  not rhinestone                     not rhinestone
#    24                  not rhinestone                     not rhinestone
#    25                  not rhinestone                     not rhinestone
#    26                  not rhinestone                     not rhinestone
#    27                  not rhinestone                     not rhinestone
#    28                  not rhinestone                     not rhinestone
#    29                  not rhinestone                     not rhinestone
#    30                  not rhinestone                     not rhinestone
#    31                  not rhinestone                     not rhinestone
#    32                  not rhinestone                     not rhinestone
#    33                  not rhinestone                     not rhinestone
#    34                  not rhinestone                     not rhinestone
#    35                  not rhinestone                     not rhinestone
#    36                  not rhinestone                     not rhinestone
#    37                  not rhinestone                     not rhinestone
#    38                  not rhinestone                     not rhinestone
#    39                  not rhinestone                     not rhinestone
#    40                  not rhinestone                     not rhinestone
#    41                  not rhinestone                     not rhinestone
#    42                  not rhinestone                     not rhinestone
#    43                  not rhinestone                     not rhinestone
#    44                  not rhinestone                     not rhinestone
#    45                      rhinestone                     not rhinestone
#    46                  not rhinestone                     not rhinestone
#    47                  not rhinestone                     not rhinestone
#    48                  not rhinestone                     not rhinestone
#    49                  not rhinestone                     not rhinestone
#    50                  not rhinestone                     not rhinestone
#    51                  not rhinestone                     not rhinestone
#    52                  not rhinestone                     not rhinestone
#    53                  not rhinestone                     not rhinestone
#    54                  not rhinestone                     not rhinestone
#    55                      rhinestone                     not rhinestone
#    56                  not rhinestone                     not rhinestone
#    57                      rhinestone                     not rhinestone],
#   ['embellishment accuracy: 96.20689655172414',
#       embellishment_patches_actual embellishment_patches_predicted
#    0                   not patches                     not patches
#    1                   not patches                     not patches
#    2                   not patches                     not patches
#    3                   not patches                     not patches
#    4                   not patches                     not patches
#    5                   not patches                     not patches
#    6                   not patches                     not patches
#    7                   not patches                     not patches
#    8                   not patches                     not patches
#    9                   not patches                     not patches
#    10                  not patches                     not patches
#    11                  not patches                     not patches
#    12                  not patches                     not patches
#    13                  not patches                     not patches
#    14                  not patches                     not patches
#    15                  not patches                     not patches
#    16                  not patches                     not patches
#    17                      patches                     not patches
#    18                      patches                     not patches
#    19                  not patches                     not patches
#    20                  not patches                     not patches
#    21                  not patches                     not patches
#    22                  not patches                     not patches
#    23                  not patches                     not patches
#    24                  not patches                     not patches
#    25                      patches                     not patches
#    26                      patches                     not patches
#    27                  not patches                     not patches
#    28                  not patches                     not patches
#    29                  not patches                     not patches
#    30                  not patches                     not patches
#    31                  not patches                     not patches
#    32                  not patches                     not patches
#    33                  not patches                     not patches
#    34                  not patches                     not patches
#    35                  not patches                     not patches
#    36                  not patches                     not patches
#    37                  not patches                     not patches
#    38                  not patches                     not patches
#    39                  not patches                     not patches
#    40                  not patches                     not patches
#    41                  not patches                     not patches
#    42                  not patches                     not patches
#    43                  not patches                     not patches
#    44                  not patches                     not patches
#    45                  not patches                     not patches
#    46                  not patches                     not patches
#    47                  not patches                     not patches
#    48                  not patches                     not patches
#    49                  not patches                     not patches
#    50                  not patches                     not patches
#    51                  not patches                     not patches
#    52                  not patches                     not patches
#    53                  not patches                     not patches
#    54                  not patches                     not patches
#    55                  not patches                     not patches
#    56                  not patches                     not patches
# ...
#    16                  not beaded                     not beaded
#    17                  not beaded                     not beaded
#    18                  not beaded                     not beaded
#    19                  not beaded                     not beaded
#    20                  not beaded                     not beaded
#    21                  not beaded                     not beaded
#    22                  not beaded                     not beaded
#    23                  not beaded                     not beaded
#    24                  not beaded                     not beaded
#    25                  not beaded                     not beaded
#    26                  not beaded                     not beaded
#    27                  not beaded                         beaded
#    28                      beaded                         beaded
#    29                      beaded                         beaded
#    30                  not beaded                     not beaded
#    31                      beaded                     not beaded
#    32                  not beaded                     not beaded
#    33                  not beaded                     not beaded
#    34                  not beaded                     not beaded
#    35                  not beaded                     not beaded
#    36                  not beaded                     not beaded
#    37                  not beaded                     not beaded
#    38                  not beaded                     not beaded
#    39                  not beaded                     not beaded
#    40                  not beaded                     not beaded
#    41                  not beaded                     not beaded
#    42                  not beaded                     not beaded
#    43                  not beaded                     not beaded
#    44                  not beaded                     not beaded
#    45                  not beaded                     not beaded
#    46                  not beaded                     not beaded
#    47                  not beaded                     not beaded
#    48                  not beaded                     not beaded
#    49                  not beaded                     not beaded
#    50                  not beaded                     not beaded
#    51                  not beaded                     not beaded
#    52                  not beaded                     not beaded
#    53                  not beaded                     not beaded
#    54                  not beaded                     not beaded
#    55                  not beaded                     not beaded
#    56                  not beaded                     not beaded
#    57                  not beaded                     not beaded]],
#  [['style accuracy: 88.87878787878788',
#        style_glam_actual style_glam_predicted
#    0                glam             not glam
#    1            not glam             not glam
#    2                glam             not glam
#    3            not glam             not glam
#    4            not glam             not glam
#    ..                ...                  ...
#    655          not glam             not glam
#    656          not glam             not glam
#    657          not glam             not glam
#    658          not glam             not glam
#    659          not glam             not glam
#
#    [660 rows x 2 columns]],
#   ['style accuracy: 78.3030303030303',
#        style_businesscasual_actual style_businesscasual_predicted
#    0                businesscasual             not businesscasual
#    1                businesscasual             not businesscasual
#    2            not businesscasual             not businesscasual
#    3            not businesscasual             not businesscasual
#    4            not businesscasual                 businesscasual
#    ..                          ...                            ...
#    655          not businesscasual             not businesscasual
#    656          not businesscasual                 businesscasual
#    657          not businesscasual             not businesscasual
#    658          not businesscasual             not businesscasual
#    659          not businesscasual             not businesscasual
#
#    [660 rows x 2 columns]],
#   ['style accuracy: 68.96969696969697',
#        style_classic_actual style_classic_predicted
#    0                classic             not classic
#    1                classic             not classic
#    2                classic             not classic
#    3            not classic             not classic
#    4            not classic                 classic
#    ..                   ...                     ...
#    655              classic             not classic
#    656          not classic             not classic
#    657          not classic             not classic
#    658          not classic             not classic
#    659          not classic             not classic
#
#    [660 rows x 2 columns]],
#   ['style accuracy: 70.42424242424242',
#        style_modern_actual style_modern_predicted
#    0                modern                 modern
#    1                modern                 modern
#    2                modern                 modern
#    3            not modern                 modern
#    4                modern                 modern
#    ..                  ...                    ...
#    655          not modern             not modern
#    656          not modern             not modern
#    657          not modern             not modern
#    658          not modern             not modern
#    659              modern             not modern
#
#    [660 rows x 2 columns]],
#   ['style accuracy: 87.18181818181819',
#        style_romantic_actual style_romantic_predicted
#    0                romantic             not romantic
#    1                romantic             not romantic
#    2                romantic             not romantic
#    3            not romantic             not romantic
#    4            not romantic             not romantic
#    ..                    ...                      ...
#    655          not romantic             not romantic
#    656              romantic             not romantic
#    657          not romantic             not romantic
#    658          not romantic             not romantic
#    659          not romantic             not romantic
#
#    [660 rows x 2 columns]],
#   ['style accuracy: 75.15151515151514',
#        style_casual_actual style_casual_predicted
#    0                casual                 casual
#    1            not casual             not casual
#    2            not casual             not casual
#    3                casual             not casual
#    4                casual                 casual
#    ..                  ...                    ...
#    655              casual                 casual
#    656              casual                 casual
#    657              casual                 casual
#    658              casual                 casual
#    659              casual                 casual
#
#    [660 rows x 2 columns]],
#   ['style accuracy: 79.72727272727272',
#        style_edgy_actual style_edgy_predicted
#    0            not edgy             not edgy
#    1            not edgy             not edgy
#    2            not edgy             not edgy
#    3            not edgy                 edgy
#    4                edgy                 edgy
#    ..                ...                  ...
#    655          not edgy             not edgy
#    656              edgy             not edgy
#    657          not edgy             not edgy
#    658          not edgy             not edgy
#    659          not edgy             not edgy
#
#    [660 rows x 2 columns]],
#   ['style accuracy: 94.06060606060606',
#        style_retro_actual style_retro_predicted
#    0            not retro             not retro
#    1                retro             not retro
#    2            not retro             not retro
#    3                retro             not retro
#    4            not retro             not retro
#    ..                 ...                   ...
#    655          not retro             not retro
#    656          not retro             not retro
#    657          not retro             not retro
#    658          not retro             not retro
#    659          not retro             not retro
#
#    [660 rows x 2 columns]],
#   ['style accuracy: 84.69696969696969',
#        style_androgynous_actual style_androgynous_predicted
#    0            not androgynous             not androgynous
#    1            not androgynous             not androgynous
#    2            not androgynous             not androgynous
#    3                androgynous             not androgynous
#    4                androgynous                 androgynous
#    ..                       ...                         ...
#    655          not androgynous             not androgynous
#    656          not androgynous             not androgynous
#    657          not androgynous             not androgynous
#    658          not androgynous             not androgynous
#    659          not androgynous             not androgynous
#
#    [660 rows x 2 columns]],
#   ['style accuracy: 96.36363636363636',
#        style_athleisure_actual style_athleisure_predicted
#    0            not athleisure             not athleisure
#    1            not athleisure             not athleisure
#    2            not athleisure             not athleisure
#    3            not athleisure             not athleisure
#    4            not athleisure             not athleisure
#    ..                      ...                        ...
#    655          not athleisure             not athleisure
#    656          not athleisure             not athleisure
#    657              athleisure             not athleisure
#    658          not athleisure             not athleisure
#    659          not athleisure             not athleisure
#
#    [660 rows x 2 columns]],
#   ['style accuracy: 88.30303030303031',
#        style_boho_actual style_boho_predicted
#    0            not boho             not boho
#    1            not boho             not boho
#    2            not boho             not boho
#    3            not boho             not boho
#    4            not boho             not boho
#    ..                ...                  ...
#    655          not boho             not boho
#    656          not boho             not boho
#    657          not boho             not boho
#    658          not boho             not boho
#    659          not boho             not boho
#
#    [660 rows x 2 columns]]],
#  [['occasion accuracy: 76.18974923210929',
#        occasion_weekend_actual occasion_weekend_predicted
#    0                   weekend                    weekend
#    1                   weekend                    weekend
#    2               not weekend                    weekend
#    3                   weekend                    weekend
#    4                   weekend                    weekend
#    ..                      ...                        ...
#    655                 weekend                    weekend
#    656                 weekend                    weekend
#    657                 weekend                    weekend
#    658                 weekend                    weekend
#    659                 weekend                    weekend
#
#    [660 rows x 2 columns]],
#   ['occasion accuracy: 77.06803282446248',
#        occasion_work_actual occasion_work_predicted
#    0                   work                not work
#    1                   work                not work
#    2                   work                not work
#    3               not work                not work
#    4               not work                    work
#    ..                   ...                     ...
#    655             not work                not work
#    656             not work                not work
#    657             not work                not work
#    658                 work                    work
#    659             not work                not work
#
#    [660 rows x 2 columns]],
#   ['occasion accuracy: 76.88516022555356',
#        occasion_daytonight_actual occasion_daytonight_predicted
#    0                   daytonight                    daytonight
#    1                   daytonight                    daytonight
#    2                   daytonight                    daytonight
#    3                   daytonight                    daytonight
#    4                   daytonight                    daytonight
#    ..                         ...                           ...
#    655             not daytonight                    daytonight
#    656             not daytonight                    daytonight
#    657             not daytonight                    daytonight
#    658                 daytonight                    daytonight
#    659             not daytonight                    daytonight
#
#    [660 rows x 2 columns]],
#   ['occasion accuracy: 78.06812451290514',
#        occasion_nightout_actual occasion_nightout_predicted
#    0                   nightout                    nightout
#    1                   nightout                not nightout
#    2                   nightout                not nightout
#    3                   nightout                not nightout
#    4               not nightout                not nightout
#    ..                       ...                         ...
#    655             not nightout                not nightout
#    656             not nightout                not nightout
#    657             not nightout                not nightout
#    658             not nightout                not nightout
#    659             not nightout                not nightout
#
#    [660 rows x 2 columns]],
#   ['occasion accuracy: 86.1551368450007',
#        occasion_vacation_actual occasion_vacation_predicted
#    0               not vacation                not vacation
#    1               not vacation                not vacation
#    2               not vacation                not vacation
#    3               not vacation                not vacation
#    4               not vacation                not vacation
#    ..                       ...                         ...
#    655             not vacation                not vacation
#    656             not vacation                not vacation
#    657             not vacation                not vacation
#    658             not vacation                not vacation
#    659             not vacation                not vacation
#
#    [660 rows x 2 columns]],
#   ['occasion accuracy: 97.24329528262963',
#        occasion_workout_actual occasion_workout_predicted
#    0               not workout                not workout
#    1               not workout                not workout
#    2               not workout                not workout
#    3               not workout                not workout
#    4               not workout                not workout
#    ..                      ...                        ...
#    655                 workout                not workout
#    656             not workout                not workout
#    657             not workout                not workout
#    658             not workout                not workout
#    659             not workout                not workout
#
#    [660 rows x 2 columns]],
#   ['occasion accuracy: 94.21409251363866',
#        occasion_coldweather_actual occasion_coldweather_predicted
#    0               not coldweather                not coldweather
#    1               not coldweather                not coldweather
#    2               not coldweather                not coldweather
#    3               not coldweather                not coldweather
#    4               not coldweather                not coldweather
#    ..                          ...                            ...
#    655             not coldweather                not coldweather
#    656             not coldweather                not coldweather
#    657             not coldweather                not coldweather
#    658                 coldweather                    coldweather
#    659             not coldweather                not coldweather
#
#    [660 rows x 2 columns]]]]

# %%
end = pd.datetime.now()

# %%
print(end-start)
# Out:
# 0:36:10.410516
